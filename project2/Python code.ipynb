# %%
# Natural language processing library.
import nltk
import pandas as pd
import numpy as np
from io import StringIO

# need to use once to download nltk on your computer.
# nltk.download()

# %% [markdown]
# Vu qu'on a une librarie qui nous permet de faire pas mal de choses, on va:
# - mettre tout en minuscule
# - retirer la ponctuation
# - retirer tous les nombres et caractères non alphanumériques
# - les tokeniser: donc séparer les mots
# - retirer les stop words (and, the, etc)
# - stemmer -> avoir que la racine de chaque mots
#
# à partir de là on aura déjà un dataset plus ou moins propre =)

# %%
# Create empty arrays wich will get textfile data
data_neg = []
data_pos = []
data_test = []

# %%
# Each new line will be a new element of array
with open ("twitter-datasets/train_neg_full.txt", "r", encoding="utf8") as myfile:
    data_neg = myfile.readlines()
with open ("twitter-datasets/train_pos_full.txt", "r", encoding="utf8") as myfile:
    data_pos = myfile.readlines()
with open ("twitter-datasets/test_data.txt", "r", encoding="utf8") as myfile:
    data_test = myfile.readlines()

# %%
# Out:
# ['vinco tresorpack 6 ( difficulty 10 of 10 object : disassemble and reassemble the wooden pieces this beautiful wo ... <url>\n',
#  'glad i dot have taks tomorrow ! ! #thankful #startho\n',
#  '1-3 vs celtics in the regular season = were fucked if we play them in the playoffs\n',
#  "<user> i could actually kill that girl i'm so sorry ! ! !\n",
#  '<user> <user> <user> i find that very hard to believe im afraid\n',
#  'wish i could be out all night tonight ! <user>\n',
#  '<user> i got kicked out the wgm\n',
#  'rt <user> <user> <user> yes she is ! u tell it ! my lips are closed okay\n',
#  'why is she so perfect <url>\n',
#  '<user> hi harry ! did u havea good time in aus ? i didnt get 2 see u maybe next year ! follow me back if u can , would bea dreamcome truex\n',
#  'introduction to programming with c + + ( 2nd edition this solid foundation in the basics of c + + programming will ... <url>\n',
#  'introduction to programming with c + + ( 2nd edition this solid foundation in the basics of c + + programming will ... <url>\n',
#  'introduction to programming with c + + ( 2nd edition this solid foundation in the basics of c + + programming will ... <url>\n',
#  "<user> i'm white . #aw\n",
#  "<user> dan i love and miss you ! don't be sad #wheresthegeneral\n",
#  'so many wonderful building in dc but still miss you <user>\n',
#  "<user> it's annoying because i secretly find it so good ...\n",
#  'the post-boom in spanish american fiction ( suny series in latin american and iberian thought and culture what ... <url>\n',
#  'layers of the heart ( paperback this journey was inspired by a recent robbery that took place in the united sta ... <url>\n',
#  'layers of the heart ( paperback this journey was inspired by a recent robbery that took place in the united sta ... <url>\n',
#  'guess who texted me again and wants us back ( ( ( <user> <user> <user>\n',
#  '<user> # 2 farrow ( v a litter offence ; wilful dispersal of piglets ~ continued\n',
#  "99000 people at barca's ground tonight are gonna see chelsea get absolutly destroyed ! the other 100million will have to watch on telly\n",
#  'mlb 07 the show ( video game mlb 07 : the show <url>\n',
#  'rt if #justinbieber is not following you\n',
#  'rt if #justinbieber is not following you\n',
#  'rt if #justinbieber is not following you\n',
#  'why should i even care ? she dont want my white ass anyways\n',
#  'ugh idk why i got my hopes up ! ! ! my plans never work out ! ! !\n',
#  '<user> ummm playing trials hd and ignoring the fact i need to be up at 7\n',
#  'trying to get <user> tickets for the vancouver show too . row 1 for $ 1500 ? haaa #nothappening\n',
#  '04x27 custom picture frame / poster frame 1.5 " wide complete american maple brown frame ( 17015 this frame is m ... <url>\n',
#  'sooo i missed music class ! does this mean ! .. mi ago fail tha test thurs .. ... cuz mi nah study all that music\n',
#  "<user> not when i'm straight and i'm taller than the cute boys\n",
#  '<user> <user> bloodforge not worth fighting to get . decent combat , visuals stay same all game , and story non-existent .\n',
#  'i really want him to do something special and spontaneous ... gotta feeling something wrong , so dat wont be happening\n',
#  'bye bye beach and buddies ( @ fort lauderdale-hollywood international airport ( fll ) w / 47 others ) <url>\n',
#  "damn it , just saw a spoiler that told me how joffrey dies . now there won't be as much satisfaction when i see it on tv . #gameofthrones\n",
#  "just realized i still don't know what my prom dates tux looks like .. hmm .. #subtweet #superobvioussubtweet #showme <\n",
#  "marion zimmer bradley's ravens of avalon [ with earphones ] ( playaway adult fiction marion zimmer bradleys belo ... <url>\n",
#  'why do i get treated like this\n',
#  "<user> they're the best cookies that i've tried . but ig you don't even like chewy cookies , so maybe they wouldn't appeal to you\n",
#  '<user> haha afraid not stir fry veg and chicken\n',
#  '<user> we always have finals on saturdays\n',
#  '[ rivals ] <url> war room 4/23 ( rivals david lockwood and spencer leftwich are just two a ... <url> #arizona\n',
#  "<user> ow im very sorry : ' - ( but im not too know englis ... therefore : ' - (\n",
#  "<user> i'm not surprised you shouldn't do that ! ! xx\n",
#  "all these people that meet <user> and get dmed by her .. still haven't had my first tweet\n",
#  'suffering from post-festival disorder\n',
#  '<user> their not getting divorced !\n',
#  '<user> hahahah ok ok sorry do you like the name evey ? xd\n',
#  '<user> hahahah ok ok sorry do you like the name evey ? xd\n',
#  '<user> hahahah ok ok sorry do you like the name evey ? xd\n',
#  'omfg ... they did a hello kitty shoot on antm ... so jealous !\n',
#  '<user> stab in the heart . i really wanted to be your friend on facebook\n',
#  'walthers proto 2000 ho scale diesel emd f7a powered - standard dc - soo line #2225 - b with mars light ( red , white <url>\n',
#  'i am watching t . v nothing is on\n',
#  'assalamualaikum .. morning people .. have to stay awake even though my eyes are too heavy\n',
#  "everyones at yd ... couldn't get an invite ? !\n",
#  '<user> <user> you guys honestly suck\n',
#  'medium cherry & black 60 " corner tv stand by powell - medium wood ( 533-275 contemporary 60 " wide corner tv sta ... <url>\n',
#  'o2 xda trion minisync - complete essentials kit ( european outlet plug , cleartouch anti-glare the minisync - co ... <url>\n',
#  "i just wanna text him . only him ... he's the one person that can cheer me up\n",
#  "<user> hahaha you know it ! i'm on a mission .. its killing me though\n",
#  '<user> > what if i wanted to hang out on your 18th birthday .\n',
#  'cables to go 03011 db25 female / female null modem cable , beige ( 6 feet / 1.82 meters our line of null modem seria ... <url>\n',
#  "<user> i don't know joey\n",
#  'only a week and a half left of freshman year #sadtweet\n',
#  'only a week and a half left of freshman year #sadtweet\n',
#  'emotionally taken for granted\n',
#  "<user> thanks for trying veevs but he won't call\n",
#  "women's merrell moab waterproof ( 5.5 m in dusty olive <url>\n",
#  "it's clearly that i miss my young sisters . when i played with a 6 year old girl i felt it !\n",
#  "<user> <user> <user> wish he made an under 18 ' s xxx\n",
#  'pouring rain outside . wish i could go out\n',
#  'science test tomorrow ? not the deal !\n',
#  'where you at anyways ? rt <user> <user> i miss u\n',
#  'tht had to be one of the worst voicemails i ever got\n',
#  '<user> i know thought i woulda been over it by now aha\n',
#  '#loitersquad need to hurry up n come on\n',
#  'newpics #nsfw #sexy hot blonde ready for the game of love ( 1 <url>\n',
#  'hannah wants playing at dc on saturday , sooo wanna go #notfairrr\n',
#  'jersey shore 13x25 custom picture frame / poster frame 2 " wide complete black wood frame (8 941 this frame is m ... <url>\n',
#  'isn\'t it strange to call it " past " when we keep thinking of it every second ? ! !\n',
#  'star brite economy boat hook ( 4-8- feet telescoping pole extends from 4 ( 124 cm ) to 8 ( 243 cm ) with a special f ... <url>\n',
#  '<user> i love cambon ! my first rouge coco and i adore it ! too bad i smooched it in the cap . tragedy\n',
#  'coastal walks : normandy and brittany ( footpaths of europe <url>\n',
#  'what are you confident in ? ( a devotional ) ( " i\'ll use the three hundred men ... " judges 7:7 endurance and confid ... <url>\n',
#  "<user> what's happened ? xxx\n",
#  '" <user> the worst way to miss a person is to be sitting right beside them knowing things will never be the same . " fml\n',
#  'so justin is in london and i am off to school\n',
#  "<user> <user> the two of you have to talk when you're both not upset na ! ! > < tama na galit pareho lang kayong malungkot .\n",
#  'natrum muriaticum ( potency : lm 25 natrum muriaticum is a homeopathic remedy available as medicated sugar pelle ... <url>\n',
#  "there's actually no coffee in my house #breakingdown\n",
#  'seriously what about jerking-off a strapon ? rt <user> the penalty for #masturbation in indonesia is decapitation .\n',
#  'k ! hopeless ang packaging . editing pictures is not that easy . seriously i really need help #shitty\n',
#  '<user> hihi ... . bt i havnt hav anything\n',
#  'sex , straight up ( harlequin blaze ) ( mass market paperback meeting a handsome loner on a deserted beach in the ... <url>\n',
#  "wondering when she'll talk to me again\n",
#  "i feel like being in the bed resting ' i didnt feel like coming to school today\n",
#  'dvd-learn to play irish fiddle # 1 ( dvd kevin burkes easygoing manner and encouraging teaching style invite yo ... <url>\n',
#  'dvd-learn to play irish fiddle # 1 ( dvd kevin burkes easygoing manner and encouraging teaching style invite yo ... <url>\n',
#  'and all the days you let me cry ! !\n',
#  'anissamontana _ by lornai .. if you were still in the group chat you would know this\n',
#  '#oomf play to much .\n',
#  '48 " three-drawer chest by hooker furniture - natural wood ( 977-85- 122 48 " three-drawer chest . this credenza a ... <url>\n',
#  "for the person who asked why i'm always bent over in photos , good question . i don't know , maybe cause i'm quite tall and i hate my height\n",
#  "<user> i can't tell you , none of her college mate shave heard about her or seen her in 2 days ,\n",
#  '<user> oh ... i thought ... you know , that we would ... you , know ... nevermind ...\n',
#  'why is the house so cold\n',
#  "<user> har then how ? we can't whatsapp like a boss ald tmrw refresh again !\n",
#  'but i was nice all day\n',
#  'stronghold legends ( dvd-rom relive 3 of the greatest legends of historyproduct informationan rts experience fr ... <url>\n',
#  'why am i still sick\n',
#  'i wish i could play an instrument\n',
#  '<user> buke sombong tp kesibukkan maso ni jh on twitter , hewhew\n',
#  '<user> i know thanks . #teamlilrowdy\n',
#  'i miss being at the sports plex all the time ! i love that place .\n',
#  'druid quest ( paperback in first century ad britannia , after burning the oaken groves and the druid priest , the ... <url>\n',
#  '" <user> in pizza hut with these goons ! i gin miss wednesday\'s with themm <3 <3 <url> jealous : $\n',
#  "belkin soho f1ds102l vga and usb 2 port in / out kvm switch ( black ) ( personal computers with belkin's newly rede ... <url>\n",
#  "belkin soho f1ds102l vga and usb 2 port in / out kvm switch ( black ) ( personal computers with belkin's newly rede ... <url>\n",
#  'ask the critic ? your <user> foodie qs answered cc : <user> <user> <user> ( + 3 others <url>\n',
#  'rt <user> <--- the real < - __ - ) > #boss . - - facts ! ! !\n',
#  '<user> idk , lol haha i heard it was crazy ( ( (\n',
#  '<user> idk , lol haha i heard it was crazy ( ( (\n',
#  'not enough sleep\n',
#  'not enough sleep\n',
#  'not enough sleep\n',
#  'not enough sleep\n',
#  "<user> that's good it will help ! you cant miss it you'll fail the whole thing\n",
#  '<user> mons go bersih , another teacher come and teach us , but he dint teach us anything wasting time only\n',
#  "i heard but i am as motivated as ever ! do you still have your dvd's <user> laureen insanity is a beast ! one day & i gave up .\n",
#  'shamu believe dvd ( seaworld ) ( dvd the title of this show is called " believe this is a show about the killer ... <url>\n',
#  'season finale of fantasy factory in an hr\n',
#  'too bad .. i super wanna watch the avengers ..\n',
#  "<user> that's a pic of your last ballet class before you go to college ... #gonnamissyousomuchtweet\n",
#  "<user> greyson chance has less fans here.but he'll be here on april 24-28.why don't u guys come to taiwan ( come here please\n",
#  '" <user> <user> but did you even know about the trimurti , ahimsa and moksha before year 9 ? " / loool go away allow me ok\n',
#  "<user> aaw that's what you have ?\n",
#  'do you ever get it when you miss someone so much your heart hurts xoxo <user>\n',
#  "original pocket farkel miniature set ( yellow dice one of the world's best dice games , pocket farkel is a fun , ... <url>\n",
#  "original pocket farkel miniature set ( yellow dice one of the world's best dice games , pocket farkel is a fun , ... <url>\n",
#  'for the first time in my life i can say that bara let me down #msqueunclub\n',
#  "i'm sorry but with gary cahill in defence <user> are going to get destroyed . barca to win by 2\n",
#  "<user> just wondering , where did you get that case from ? : o and it's heaps hard to find pretty iphone 3gs cases\n",
#  "pee-wee's playhouse # 1 - seasons 1 and 2 ( dvd studio : image entertainment release date : 09/04 / 2007 <url>\n",
#  "so bad at this logo's game\n",
#  '<user> so i come to my room and its freezing ... this double duvet and blanket better cut it #begging #poverty eh ? . sorry .\n',
#  'wine glass id tags ( card symbols these durable snap-on clips let your guest identify his or her own stemware g ... <url>\n',
#  'wine glass id tags ( card symbols these durable snap-on clips let your guest identify his or her own stemware g ... <url>\n',
#  'wine glass id tags ( card symbols these durable snap-on clips let your guest identify his or her own stemware g ... <url>\n',
#  'hmm , barca to win 3-1 i think\n',
#  '<user> please wish me luck i have my english exam today !\n',
#  "<user> <user> i took pictures from a donkey's rectum ( ( ( / issuestemporaryrestrainingorderaswell /\n",
#  "fly fishing colorado's major 6 ( dvd 2 dvd set on fly fishing and instructional materials from top guides ! ever ... <url>\n",
#  "fly fishing colorado's major 6 ( dvd 2 dvd set on fly fishing and instructional materials from top guides ! ever ... <url>\n",
#  'rt <user> massive gud luck 2 da boyz 2day let end adecent season on ahigh so pissed i cant play thou ... <url>\n',
#  'mondo * arc ( news mondo * arc 1.0 device : ios ipad only category : news price : free , version : 1.0 ( itunes ) description : ... <url>\n',
#  'getting a random text saying " hey was listening to michael jackson made me think of you hope you\'re ok " ffs\n',
#  'hokay this day is taking the mick seriously anything else wanna happen ? at breaking point right now\n',
#  'battery grip for canon eos 50d , 40d , 30d & 20d ( bp - 511a li-ion batteries the perfect replacement grip for the ... <url>\n',
#  "i'll have to spam my man soon . i feel like a horrible girlfriend coz i haven't yet and he's done it twice .\n",
#  'i think i lost one of my rings\n',
#  '<user> he cried after the match it was heartbreaking < \\ 3\n',
#  '<user> i have one gma left my moms mom . i sure miss my gma and wish i had more time with my gpa . miss them !\n',
#  'this weather is so minging\n',
#  'embassy large genuine leather purse ( apparel embassy large genuine leather purse . measures 141/2 " x 91/2 " x 51 ... <url>\n',
#  'embassy large genuine leather purse ( apparel embassy large genuine leather purse . measures 141/2 " x 91/2 " x 51 ... <url>\n',
#  'please pray for her and her family in syria during this time . they must be in so much shock ya rab .\n',
#  "<user> 5k i could cry i'm so unfit !\n",
#  '<user> <user> lol of course , there wass more people just no room\n',
#  'searching up universitys in a library while eating a ginger bread man ... i need to loose weight but i cant seem to stop eating\n',
#  'this gurl is olwaiz offline y na\n',
#  'dell inspiron 2500 piii 850 128mb memory ram upgrade ( a-tech brand 128mb pc100 sdram so-dimm for dell inspiron ... <url>\n',
#  'dell inspiron 2500 piii 850 128mb memory ram upgrade ( a-tech brand 128mb pc100 sdram so-dimm for dell inspiron ... <url>\n',
#  'dell inspiron 2500 piii 850 128mb memory ram upgrade ( a-tech brand 128mb pc100 sdram so-dimm for dell inspiron ... <url>\n',
#  'dell inspiron 2500 piii 850 128mb memory ram upgrade ( a-tech brand 128mb pc100 sdram so-dimm for dell inspiron ... <url>\n',
#  'dell inspiron 2500 piii 850 128mb memory ram upgrade ( a-tech brand 128mb pc100 sdram so-dimm for dell inspiron ... <url>\n',
#  "i hate it when people don't put any smileys in a text . it makes me feel like im the only person who has emotions\n",
#  '<user> oh nice , i might miss them then\n',
#  'vector ? electromate 1000w rechargeable generator ( lawn & patio generate the power you need where you need it w ... <url>\n',
#  'green with envy : a whole new way to look at financial ( un ) happiness ( paperback a silent struggle with our mone ... <url>\n',
#  "5 am already and i can't sleep (\n",
#  '20x28 custom picture frame / poster frame 1.25 " wide complete distressed maple brown frame ( 26032 this frame i ... <url>\n',
#  "<user> lool don't worry its going to rain later apparently lol\n",
#  "all i want is my gudmornin text an a lil convo to keep my day goin #that's all\n",
#  'i guess i won\'t get a " happy birthday " tweet from <user>\n',
#  '2 amigos design protector skin decal sticker for apple macbook pro 17 inch ( original , separate trackpad button ... <url>\n',
#  'hasbro dream town rose petal cottage : rose petal lounge chair ( toy <url>\n',
#  'hasbro dream town rose petal cottage : rose petal lounge chair ( toy <url>\n',
#  "<user> please follow me ? everytime i ask i get a follower but it turns out it isn't you\n",
#  'glasses are so scratched i cant see through them , blind with or without glasses now\n',
#  'sanyo brand coupler - 1 - phone recording device ( office supply / other sanyo brand coupler - 1 - phone recording ... <url>\n',
#  'sanyo brand coupler - 1 - phone recording device ( office supply / other sanyo brand coupler - 1 - phone recording ... <url>\n',
#  'this has gt to b da worse hangover ever i cant stop puking\n',
#  'and it really sucks that i have i wait til i got home to see her\n',
#  "naw ... if <user> to miss it , so did you . sry rt <user> oh ... you just ain't ( cont ) <url>\n",
#  'what is wrong with everyone to day it\'s friday " it\'s friday friday getting down on friday " lol i love friday if that beth girl would stop\n',
#  'sick . somebody come take care of me\n',
#  "mike hotek'smcts self-paced training kit ( exam 70-432 microsoft sql server 2008 - implementation and maintenan ... <url>\n",
#  "i've got all the worst lessons on fridays\n",
#  'recent developments on debris flows ( lecture notes in earth sciences the book gives a general overview of rece ... <url>\n',
#  'had 2 make a new twitter sooo help mee out\n',
#  'nicole tortures me by tickling me to death ( (\n',
#  '<user> sit and reach > ( (\n',
#  'digital spectrum memoryframe mf - 8104 premium 10.4- inch wireless digital frame ( electronics the mf - 8104 wireles ... <url>\n',
#  "<user> please notice me i've been trying since the day you got twitter , 28th march 2009 , please ? #believe i love you 37\n",
#  'stomach ache i juss ate too much tonight ! ! * doris voice *\n',
#  'the feeling of dentist later makes me wanna cry\n',
#  "there's a man in the corner who reminds me of the ginger scary man from holiday #scary #ginger #ohno #notgoodnews\n",
#  'so fruitful a fish ( biology and resource management series aquaculture , or " fish farming " is a rapidly growing ... <url>\n',
#  "<user> haha i know , what's happening to me hate studying stress when i am so stressed ! !\n",
#  'kradji :: a child of cambodia ( children of the world ( blackbirch ) ) ( hardcover <url>\n',
#  'kradji :: a child of cambodia ( children of the world ( blackbirch ) ) ( hardcover <url>\n',
#  "cute toddler lady bug costume ( 2-4 t everyone's favorite little lady bug has just become the most adorable litt ... <url>\n",
#  "cute toddler lady bug costume ( 2-4 t everyone's favorite little lady bug has just become the most adorable litt ... <url>\n",
#  'the book of the unknown : tales of the thirty-six ( paperback marvelous and mystical stories of the thirty-six a ... <url>\n',
#  'aurora plush 12 " esmeralda flopsie ( toy aurora only uses lock washer or embroidered eyes and nose for safety . <url>\n',
#  'i want to go to prom #waaahhh\n',
#  'dell inspiron mini duo 3487fnt convertible laptop / tablet ( foggy night sometimes you want to touch . sometimes y ... <url>\n',
#  'dell inspiron mini duo 3487fnt convertible laptop / tablet ( foggy night sometimes you want to touch . sometimes y ... <url>\n',
#  'dell inspiron mini duo 3487fnt convertible laptop / tablet ( foggy night sometimes you want to touch . sometimes y ... <url>\n',
#  'why cant i be atleast be a pro skater and travel around the world and skate my life away\n',
#  '<user> are we going to get a discount on gyhab anytime soon ? it is stuck at #57 right now .\n',
#  '. 500 ( a ) , . 94 ( b ) , . 2497 ( c ) , stainless steel , two piece welded const . , plain shank fixture ball ( 1 each <url>\n',
#  'hp compaq pavilion dv4021ap notebook / laptop battery 8800mah ( high capacity replacement hp compaq pavilion dv ... <url>\n',
#  'rethinking retention in good times and bad : breakthrough ideas for keeping your best workers ( hardcover how do ... <url>\n',
#  "<user> i know . i wish i didn't give him another chance now not after what i've found out.wish i'd given someone else 2nd chance\n",
#  "<user> <user> <user> jeremy is in boston and i'm gonna be in fred tonight sorry cma\n",
#  '<user> <user> <user> happy doing the survey , i damn busy with school & work no time spare for her survey\n',
#  'americanos : latino life in the united states ( paperback this spirited bilingual book accomplishes a rare feat - ... <url>\n',
#  '<user> were so close yet so far away . im literally a few hours away from you #depressed\n',
#  'rip dick clark . you will be missed .\n',
#  'basic cell culture protocols ( methods in molecular biology in this fully revised edition of an established cla ... <url>\n',
#  '" odin ! ! " ( i never get tired of this science vs . norse myth comic <url>\n',
#  'i just want to cry i feel so sick right now diagnosis : the flue\n',
#  "<user> but it won't stop me crying myself to sleep tonight lol\n",
#  '<user> something is wrong with my phone , not working ... keep ya posted .\n',
#  "i almost forgot about one of my bestfriends d: i'm such a horrible person ! ! !\n",
#  '<user> wish i could come on your tour x\n',
#  "flokati faux fur rugs 3 ' x 5 ' ( celery green the look and feel of real fur ... even the rabbits are jealous ! our ... <url>\n",
#  '<user> nooo , thats all ive been doing i worked all weekend :/\n',
#  '<user> i wish you stop saying that . if i didnt i wouldnt have said it ! >\n',
#  'i really wish it was an actual test & not a paper\n',
#  'why do i always have to ruin a good thing ?\n',
#  '12 inch 4pin molex male to ( 2 ) 15pin sata ii female power cable ( sleeved 12 inch 4 - pin molex male to two 15 - pi ... <url>\n',
#  'lenovo thinkpad a21m 2628 - d2u 128mb memory ram upgrade ( a-tech brand 128mb pc100 sdram so-dimm for lenovo thin ... <url>\n',
#  "superman on the cover . that's a fine publication ( via <user> <url>\n",
#  'want a rt off <user> you were amazinggg last night !\n',
#  'historic print ( l be unaware of your underwear : this is a museum quality , reproduction print on premium paper ... <url>\n',
#  "<user> i was gonna do the one where we analysed a research method , but now i'm analysing a tv programme youu ? havent started yet\n",
#  'studying for science #nerdmode\n',
#  "<user> aw i'm sorry maybe it's because the slideshow is a larger , more elegant script .\n",
#  'ibm thinkcentre a52 8160 1gb memory ram kit ( 2x512mb ) ( a-tech brand 1gb ddr 2-533 ( pc2 - 4200 ) kit ( 2x512mb ) for ... <url>\n',
#  "44 ( 5-2 solar cell that also shines : luminescent ' led-type ' design breaks efficiency record #solar #efficient_led\n",
#  "i see a dozen women a day a work . but it doesn't compare to seeing my boo everyday #missher\n",
#  'today has fuckin draggged soo bad ! still got hour n a half left . fml i cba\n',
#  "<user> not even joking , why doesn't anyone believe me\n",
#  "i'm not one the phone with daja anymore\n",
#  '<user> fucked my throat swollen i loook fatt * crys * emergency makin my mum make me marac * now now lol\n',
#  '<user> im gonna be awake for awhile lol\n',
#  'all i wanna do is see my boyfriend tomorrow #feellikecrying\n',
#  'i cant sleep anymore\n',
#  'i cant sleep anymore\n',
#  'dba dba 411x street series gold disc brake rotor ( cross-drilled and slotted ) ( front , vented disc brakes austral ... <url>\n',
#  'went up town to buy a rihanna t-shirt , there was no good ones ! i only ike the ones where she has red hair\n',
#  "i want to see dream theater but it's so impossible\n",
#  'the venture bros . - season two ( dvd an inspired spoof of 1960s action cartoons such as " johnny quest , " the ven ... <url>\n',
#  'the venture bros . - season two ( dvd an inspired spoof of 1960s action cartoons such as " johnny quest , " the ven ... <url>\n',
#  '<url> i cried when i lost my mum and dad\n',
#  '<user> i really think he is gay - sorry\n',
#  "<user> haha , i know ! you could've taken the piss out of me there\n",
#  'heaven is not verbose : a notebook ( vera pavlova prose from poetry magazine why poetry is like earthworms , thou ... <url>\n',
#  '<user> ite isee how you get on to man dah one hurt doe\n',
#  'business forms , customs and accounts , for schools and colleges ( 1894 originally published in 1894 . this volu ... <url>\n',
#  '<user> > . < .. hmp u better call before i make my way over there & hugg u\n',
#  'my phone is dying where is my charger ? ? ?\n',
#  'amika ionic tourmaline hair dryer ( giraffe the new professional nrg drying system harnesses the unique ionic a ... <url>\n',
#  '<user> <user> i cant ! thats when im a bridesmaid i definately think a cheeky getaway end of august / beginning of sept ?\n',
#  'i have my car already planned out , cant wait till i can start working on it . 20 months till i can buy it though #sadtweet\n',
#  'special : white oval platter , 12.5 " ( 07-0121 item # : 07-0121 . special order item customers also search for : di ... <url>\n',
#  'loool rt <user> wen mi mada used to beat mi\n',
#  'has to be the worst day of my life\n',
#  "<user> this is what i'd hoped but i still don't think i can watch it\n",
#  'why does <user> have to be so smart thought of her leaving me to face college alone #sadab\n',
#  "<user> i honestly need to stop following back non english twitter accounts . they've taken over twitter at this hour\n",
#  '1 1/4 ( a ) , 1 3/4 ( b ) , capacity - 1 " to 1 1/2 dia . , full vinyl coating , spring steel , gripper clip ( 1 each grip ... <url>\n',
#  'this is my fav version of the song : friendly fires - blue cassette ( cover <url> via <user>\n',
#  "stop dating jerks ! : the smart woman's guide to breaking the pattern & finding the love of your life ( paperback ... <url>\n",
#  "stop dating jerks ! : the smart woman's guide to breaking the pattern & finding the love of your life ( paperback ... <url>\n",
#  "<user> lucas , eu te amo . i don't speak portugues . but i support you every single day from venezuela , say hi nievelys xx\n",
#  'how sad .. bayern beats real madrid , to play chelsea in final <url> via <user>\n',
#  '5x5 rts from favs someone\n',
#  "<user> now that dh is done you should watch <user> it's going to make you laught ! <user> is so adorable\n",
#  'that you agreed upon and that it was your will that i should remain .\n',
#  "speedo men's race endurance + polyester solid brief swimsuit ( apparel the speedo solid endurance men's brief s ... <url>\n",
#  'gymnastics ( sports challenge presents basic information on the essential skills , techniques , and equipment for ... <url>\n',
#  "<user> what if he's not there though\n",
#  'bad ones\n',
#  'aww naw , <user> done messed up them sexy elbows\n',
#  "<user> hahaha he'll just scream at me . i offered him coke with ice before as a bribe and he was like ' no . ' * goes back to gaming *\n",
#  "<user> i ordered stuff but not this weekend blah i don't have money to order more\n",
#  "<user> i'm just waiting for the day you'll notice me , waiting isn't fun 89\n",
#  "don't you guys feel restless in class ? these days the weather so hot\n",
#  '<user> ) ) what are they gonna do\n',
#  'why i do the things i do sometimes , i myself will never understand . #sadtweet\n',
#  '" <user> ( 570 i\'ll never be able to have sex on these sheets . i\'d have to cover up the eyes of every single elmo . " <user>\n',
#  'venlo portofino leather 5 pen tray ( black your personal collection of watches , jewelry , writing instruments an ... <url>\n',
#  'starting and operating a business in utah ( starting and operating a business in the u . s . starting and operatin ... <url>\n',
#  'starting and operating a business in utah ( starting and operating a business in the u . s . starting and operatin ... <url>\n',
#  'microstar int . 865gm3 - ls 1gb memory ram kit ( 2x512mb ) ( a-tech brand 1gb ddr - 266 ( pc2100 ) kit ( 2x512mb ) for mic ... <url>\n',
#  'mourning dove - audubon plush bird ( authentic bird sound mourning dove . plush squeeze bird which sounds off th ... <url>\n',
#  'mourning dove - audubon plush bird ( authentic bird sound mourning dove . plush squeeze bird which sounds off th ... <url>\n',
#  'lexmark brand x5250 - 1 - #34 high black ink ( office supply / inkjet ink lexmark brand x5250 - 1 - #34 high black ... <url>\n',
#  'amazon usa #800 faith - four week mini bible study ( becoming press mini bible studies heather bixler . in this ... <url>\n',
#  'i wonder if they still sell spao birthday cap ... i want to buy\n',
#  '<user> me too . dinners on you yeah ^ _ ^\n',
#  'now playing song " kill everybody " - skrillex scary monsters and nice sprites ( deluxe tour edition ) )\n',
#  'hate nytes like this all alone .. freaky songs keep kumn on and er damn movie or show i watch has sex scenes #fml lol\n',
#  '" <user> today is a sad day for football ... " very ! ! !\n',
#  'mu la7th ewda 3ik thalat ana eb bale ! !\n',
#  "feel like i haven't seen <user> in a yr\n",
#  '<user> <user> <user> walao , i 6pm then lec , so actually i am the foreveralone huan .\n',
#  'school on monday ... i hate it so much . - sobs -\n',
#  'box-a - 47 " hockey sticks ( 48 pack these extra sturdy sticks are made of rigid cycolac type abs plastic and com ... <url>\n',
#  '<user> i wish ! going to give kos a try this year x\n',
#  "missing <user> and my convo's\n",
#  '04x06 custom picture frame / poster frame 1.5 " wide complete antique gold wood frame (8 783 this frame is manuf ... <url>\n',
#  '<user> i hope so always make silly mistakes ! thanks though <3\n',
#  "thank you hitron looks like i won't be finishing the a-team again\n",
#  '<user> i wish you could just come home today . #ineedu\n',
#  'similac advance early shield baby formula , ready to feed , 32 - fluid ounces ( pack of 6 ) ( health and beauty new , ... <url>\n',
#  'i think bukhar is on the way\n',
#  'rehearsal without kyu\n',
#  '<user> i have uni open day in liverpool . i had tickets and everything . i hope it goes well x\n',
#  'come back to indonesia grey ! ! i have not lived to see a concert of yours . it is the last time you come to indonesia ? <user>\n',
#  'is there somebody else on your mind ?\n',
#  'crying myself to sleep some people are just so unbelievable !\n',
#  '<user> what happened to u 3 man\n',
#  'pbl photo studio tent 30 " new complete with 800 watts of light plus 6 \' stands by pbl ( electronics this is the ... <url>\n',
#  "<user> <user> <user> <user> yes especially those two they were awesooome weren't they ? ha\n",
#  'green initiative remanufactured black laser toner cartridge for hp 55a ( ce255a remanufactured replacement cart ... <url>\n',
#  'i hate it when my eraser goes missing >\n',
#  'pray for <user> family\n',
#  'battery for asus l8400 ( 4400 mah , denaq cell count : 8 capacity : 4400mah compatible parts : battl 8400 , 90 - n40bt ... <url>\n',
#  'battery for asus l8400 ( 4400 mah , denaq cell count : 8 capacity : 4400mah compatible parts : battl 8400 , 90 - n40bt ... <url>\n',
#  'waiting for aphrodite : journeys into the time before bones ( paperback " we humans are a minority of giants , stu ... <url>\n',
#  'waiting for aphrodite : journeys into the time before bones ( paperback " we humans are a minority of giants , stu ... <url>\n',
#  '<user> you think so ?\n',
#  'have i missed the bus oh\n',
#  'q3 ( 1 of 2 metta world peace hasnt really lived up to his name now suspended 7 games for elbow on james harden . #sportsprchat\n',
#  'my phone wont let me upload my pics to instagram\n',
#  "13millionswifties let's retweet this guise , please . i can't do it alone\n",
#  'ruth : under the wings of god ( hardcover this beautifully illustrated cycle of poems by john piper sheds light ... <url>\n',
#  'm551 sheridan : us airmobile tanks 1941-2001 ( new vanguard ) ( paperback one of the weaknesses of airmobile force ... <url>\n',
#  '<user> what ! ! ! whyy ! ? ? i wanna go kent !\n',
#  '<user> thanks for the inclusion\n',
#  'some good tips ( and some myth busting " squeeze the most juice out of your iphone or ipad battery " <url>\n',
#  "<user> don't say that cause you're usually right . ( ( (\n",
#  'driving home was a bitch has my pizza now mimis time\n',
#  '" <user> that\'s a wrap ! end of an era ! #desperatehousewives <url> <user> wahhh\n',
#  'nobody wants to go to the riverfest with me !\n',
#  '<user> haha damn i mean if i was in the 412 we could chill but obviously not .. haha def meet up this summer !\n',
#  'kohler k -4403-47 kathryn toilet tank , almond ( tank only kohler k -4403-47 kathryn toilet tank , almondcarry the ... <url>\n',
#  '<user> awww its pretty cool game btw\n',
#  'i am the worst procrastinator ever .\n',
#  "so i've just had my first needle stick injury . on my way to broad green for a hepatitis b injection\n",
#  'sony alpha stp-ss 3am / c shoulder strap ( cream stylish camera strap - the cream stp-ss 3am / c shoulder strap makes ... <url>\n',
#  'i forgot to put the ham in my ham sandwich\n',
#  '<user> aww me neither i might go to sleep soon though\n',
#  '<user> mizie teda rep and answer my call\n',
#  'lindsey pavao - please dont go <url>\n',
#  '<user> i have prom boo\n',
#  "<user> i'll cry if it doesn't , it's my 16th if they don't let me i'll disown them and live in a box\n",
#  "rt <user> i like frank better . rt <user> ' back to black ' is an amazing album . < < < i like ' frank ' -> <url>\n",
#  "<user> you're smoking ? how old are you ? that's bad you know ! xx\n",
#  'i wanna do something reallly amazing for my mom for mothers day , but idk what .\n',
#  '<user> and i want lasagna or pizza from pizza hut\n',
#  "<user> i can't see it though , what is the date of it ? and my mum can't get them tomorrow as she is really busy at work (\n",
#  'handstands motivational mouse pad , vision ( electronics become motivated with the motivational mouse pads . choo ... <url>\n',
#  'she just said i was gonna get wrinkles ... awesome\n',
#  'unmarketing : stop marketing . start engaging . ( kindle edition from one of the leading experts in viral and soci ... <url>\n',
#  '<user> no u idoit it was on ur pics i was looking at that\n',
#  "i miss you see ? i can't live a day without you .\n",
#  "dear arby's : it's not good mood food when the drive thru leaves out the arby's sauce ... especially since i'm now at home ...\n",
#  'bed time for me the baby is all full now as am i an now i need some sleep from this crappy past couple of days\n',
#  '3x14 custom picture frame / poster frame 1.265 " wide complete black wood frame ( 440bk this frame is manufactur ... <url>\n',
#  '#thoughtsatwalmart why are the lines so long !\n',
#  "<user> noo i have to stay up i have homework still i procastinate too much .. why can't you sleep\n",
#  '<user> serious ? ! fair play ! did you buy it in the apple shop ? because my lock button went all dodgy , but i got it in phones 4u\n',
#  "why didn't i get chop sticks with this chinese food ? da fuq\n",
#  'riding the waves : a life in sound , science , and industry ( hardcover the life and work of renaissance man leo b ... <url>\n',
#  "<user> any part of me that can be crossed is crossed for you . i know i'm being a killjoy , but it crushed me when i didn't get it .\n",
#  "my heart goes out to this little boy that just came in & had a heart attack & he's with his friends they don't know what's really going\n",
#  '<user> her last good tour , i should have went . kelis opened for her and everything\n',
#  'should be a long day tmrrw\n',
#  'hopkins 46255 power taillight converter ( misc . these units completely isolate the tow vehicle from trailer mal ... <url>\n',
#  'lowrance gk - 9 gimbal knobs ( set of 2 lowrance gk - 9 gimbal knobs set of 2compatible with the following units : ... <url>\n',
#  'this was monday ... now the sun is in #weather <url>\n',
#  'my hair is pissing me off lately bored of it\n',
#  'cranberry juice is amazing but not when you fucking breathe it in dying\n',
#  '<user> just wonering bc i didmt talk to you today\n',
#  '<user> i knoww i wish i was there tooo\n',
#  "i had the best quality time , thank you so much <user> see ya soon i'll miss ya\n",
#  "its cold and i'm running out of sweatpants ... i don't want to pull on jeans #wah\n",
#  "i'm so sick of hypoing all the time ! it's a horrible feeling\n",
#  'artec kiwi coloreflector shampoo , 33.8- ounce bottle ( health and beauty experience kiwi coloreflector , a hair c ... <url>\n',
#  'ewww omg i stink . i just smell my body and i totally stink ! goosh what to do ? ? ?\n',
#  '<user> i used to have this tabby cat , then we had to give it away ! now i have 2 lil white fluffy maltese dogs ! :d\n',
#  '<user> please help me can you promote me ?\n',
#  '<user> booo you whore\n',
#  '<user> got an injection at school tomorrow im so nervous please may i have a tweet ? xxx 25\n',
#  "quarantine at alexander abraham's ( road to avonlea as sunday school teacher rachel lynde sets out to alexander ... <url>\n",
#  "women's imaging , an issue of ultrasound clinics ( the clinics : radiology ultrasound is one of the most frequent ... <url>\n",
#  '<user> i need a horan hug . i have a fever , bad cough , and ache everywhere\n',
#  "<user> what ! ? i love those girls though ! please don't cause harm to my friends\n",
#  '<user> had the worst dream ever last night\n',
#  "<user> and don't waste gasoline on us wwoz <3 s the planet .\n",
#  "t van thay tjec ( ( ( ~ nhu shjt = = '\n",
#  "<user> that is the first one i've seen . it was on a slow road . i was shocked .\n",
#  'bones spf society 60mm slim skateboard wheels ( set of 4 this is for a set of four bones / powell 60mm skateboard ... <url>\n',
#  'bones spf society 60mm slim skateboard wheels ( set of 4 this is for a set of four bones / powell 60mm skateboard ... <url>\n',
#  'grr .. ii really wanted to go to soccer .\n',
#  '<user> stop calling me that ! ! ! and i love you tooo xxx\n',
#  "it looks like i'm looking at a ugly bitchhh # o damn i can't stare at it any lingerrr\n",
#  'just gave myself a headache & my aunt laughin ..\n',
#  'i feel for chels , i know how it feels to get into it with your mother\n',
#  "i'm in bed sick as shit all i wanna do is cuddle be rubbed and have soup and meds handy\n",
#  'just yelled at <user> and <user> out my window and got called a creep . lmao .\n',
#  "but of course .. <user> won't tweet me\n",
#  'postcards from the edge ( of america the adventures of lewis & clark <url> #travel #usa\n',
#  'now @ 4.00 am omo ~ i have to get ready for bed insomnia make me crazy kekekekekek\n',
#  "i can't sleep without <user> lorr , usually cik debab will accompany me\n",
#  'had a dream that i missed my flight to salt lake city for #deca icdc #decaproblems <user> <user>\n',
#  'had a dream that i missed my flight to salt lake city for #deca icdc #decaproblems <user> <user>\n',
#  '<user> yealahh superr evil . d: pity shen xin ren\n',
#  "<user> aw well that's no fun\n",
#  'mangos vs feugos vs elemetn tomorow night to start #beachweekend idk where to go * splits self into multiples * lol\n',
#  "<user> i can't find you in it ! i see you <user> though ! we're talkin about the ascot rehearsals last year lool\n",
#  'sometimes i just wanna go back to being a kid\n',
#  '#thingsinmylifethatarepriceless <user>\n',
#  'the aristocracy of the long robe : the origins of judicial review in america ( contributions in legal studies is ... <url>\n',
#  'the aristocracy of the long robe : the origins of judicial review in america ( contributions in legal studies is ... <url>\n',
#  'de colores and other latin american folksongs for children ( anthology ) ( spanish edition bursting with color an ... <url>\n',
#  'selective gas chromatographic detectors ( journal of chromatography library this book gives a comprehensive , up ... <url>\n',
#  'wowowow ... i need to get better ! im so bored\n',
#  'my whole body hurts worse than it did yesterday and im still being forced to go to school\n',
#  'i have gary allen in my head , a ton of homework , a twitter addiction and another long day before friday .\n',
#  ': logitech squeezebox radio music player with color screen ( black <url> usa\n',
#  'my sinuses are effed up right now\n',
#  "so the job interview wasn't great #the manager was a ass\n",
#  '# 6 coin envelope - 28 # brown kraft - ( 3 3/8 x 6 ) ( box of 1000 a quantity of 1000 - # 6 coin envelope made with ... <url>\n',
#  'lost a close family friend ( the barber in the small town my stepdad grew up in ) , after a long fight with brain cancer . rip razor ray .\n',
#  "damn i ain't got nobody to be on my arm though for my birthday\n",
#  'i hate hurting people , even if it is for the better\n',
#  'vanco vgaa - 3x s-vga with audio cable ( 3 feet the s-vga with audio cable is used to connect a computer , digital ... <url>\n',
#  'asus eee pc seashell 1215n - pu17 - rd 12.1- inch netbook ( red 12.1 " / 1366x768 ( wxga ) / intel dual core atom d525 ... <url>\n',
#  'asus eee pc seashell 1215n - pu17 - rd 12.1- inch netbook ( red 12.1 " / 1366x768 ( wxga ) / intel dual core atom d525 ... <url>\n',
#  'asus eee pc seashell 1215n - pu17 - rd 12.1- inch netbook ( red 12.1 " / 1366x768 ( wxga ) / intel dual core atom d525 ... <url>\n',
#  'asus eee pc seashell 1215n - pu17 - rd 12.1- inch netbook ( red 12.1 " / 1366x768 ( wxga ) / intel dual core atom d525 ... <url>\n',
#  "so cut my thumb wide open had to get stitches . but i'm okay .\n",
#  "thought i was gonna see my hubby on lunch but he couldn't make it\n",
#  'smirking norway killer breivik pleads not guilty ( reuters share with friends : | | world news - top stories news , news feeds and n ...\n',
#  '<user> your not coming to queensland\n',
#  'panasonic toughbook 18 512mb memory ram upgrade ( a-tech brand 512mb ddr - 266 ( pc2100 ) so-dimm for panasonic tou ... <url>\n',
#  'ewww . i hate feeling like this ! i need to get better . #wtfiswrong #sick\n',
#  '<user> i miss you more when you coming back ? ?\n',
#  "had a wicked week with my sis <user> she's goin home today\n",
#  '15x20 custom picture frame / poster frame 1.22 " wide complete cherry wood frame ( 229popch this frame is manufa ... <url>\n',
#  "can't wait to walk to work in the rain\n",
#  'feel like i have 1000 knives stabbing me in the stomach .\n',
#  'imation 11864 1/4 " slr 5 data cartridge , 1500ft , 4gb native /8 gb compressed data capacity ( 1 each - precision-en ... <url>\n',
#  'the introverted leader : building on your quiet strength ( paperback in our extroverted business culture , introv ... <url>\n',
#  'today is the saddest day but imma try to be a lil happy\n',
#  "scence i was seeck i've been desconected from twitter x vaas happenning world ?\n",
#  'super pet chinchilla 11 - inch giant run-around exercise wheel , colors vary ( misc . run-around wheels provide fre ... <url>\n',
#  '<user> you kinda did .. all i remember is at one point i was on the ground on the wood chips ! #rude\n',
#  '<user> need you to help teach me calculus for my test tomorrow .. wish you were here\n',
#  'my mum bought me choka blok gold digger dynamite icecream because im apparently a gold digger\n',
#  "<user> gyming it isn't the same alone , getting through it though\n",
#  'my dad fucking wrote on my forehead when i was asleep , people in the shop must of thought i was a right mug omggg\n',
#  'nope , this shits legit\n',
#  "it's not gonna be the same doing karaoke on the cruise this year . it's a tradition that me & <user> do bootylicious\n",
#  '<user> i thought u left me ! ! !\n',
#  "today isn't going well , keep dropping and knocking everything over , computer's broke and so is the heating\n",
#  'all by myself haha only phs baseball players will get this\n',
#  "<user> please follow me i'm a fan ! ! i exist ! ! wooohh > . < :') ) )\n",
#  '<user> i sent that so long ago ! ! ! xxx\n',
#  'the woodsmen ( paperback this novel is about the classic themes of love and loss - but while it is a tale of lo ... <url>\n',
#  'damn hard to choose\n',
#  '<user> despite being called miss hewitt , really good ! my teacher is really good looking ! ! all the kids swear at each other\n',
#  'kettlebells for dummies ( for dummies ( health & fitness ) ) ( paperback the way to a full-body workout with amazin ... <url>\n',
#  '<user> <user> <user> at home i barely am online .. <user> all liberty ... hehe ... but now even in the fc its just pics posted\n',
#  '<user> i felt ittt ! ! ! it woke me up it was scaryyy\n',
#  'cassette 2 ( american chatterbox this title features stimulating activities within a graded syllabus , giving co ... <url>\n',
#  'bhoja air owner blocked from leaving pakistan ( pakistan telegraph share with friends : | | world news - asia - pakistan news , news ...\n',
#  'but i do ! ! ( loc dogg.voice ) lol rt <user> i dont unfollow people , thats mean\n',
#  "ugg australia women's coquette slippers , 6 , chestnut ( apparel clog-inspired slipper , fully lined with genuine ... <url>\n",
#  'not liking this cold weather #summerhurryplease\n',
#  "i'm not normal no matter how much i eat i'm never full .. food is always #onmymind ! ! !\n",
#  'canon eos - 3 35mm slr camera ( body only ) ( electronics a eos - 3 slr body without the lens . the professional 35mm ... <url>\n',
#  '<user> i just am really freaking craving some rn\n',
#  '<user> nakooow cannot be . :/ resched ?\n',
#  'so hungry but scared to eat feel sick\n',
#  "<user> haha aw i know he usually does but i doubt he will if he's with us , don't think he is coming though , can't get any money xxx\n",
#  'no , such is not life ! " <user> anthony hamilton-pray for me ... i really messed up ka wknd ! but hey , such is life "\n',
#  'got a rete poorly dog\n',
#  '<user> kerrry ! ! ! i totally forgot you could have used my extra ticket but i just gave it away ( ( (\n',
#  'messi crossbar , goalpost , disallowed goal . it was just written than they were to lose\n',
#  'looking for my old car ( phoenix some 28 years ago i traded off a car that i had and had fixed up . one of those ... <url>\n',
#  '<user> yeah , ut this was extra shocking because my friends mom just passed away too , one week ago . i saw her hubby at the wake\n',
#  "<user> there's like 3 ... and all seniors wah !\n",
#  'never had the p ... im missing out\n',
#  '<user> natt please reply my twitt .\n',
#  "<user> <user> <user> <user> <user> the one who didn't asked who :p lol leo damm #caught lol\n",
#  '<user> oh awk . i just realized im to late lol\n',
#  '<user> : why is your name is asa ? pls do reply\n',
#  '<user> i knoww and my keyss\n',
#  'dead presidents . americas government on trial . ( writer don dead ex-presidents ? yes , they are deciding if th ... <url>\n',
#  'best of michael henderson ( the buddah collection bin # r04278 13 tracks1.valentine love w / jean carn ... <url>\n',
#  '<user> dude dont do this to me , just thinking about it makes me depressed\n',
#  'textbridge pro 11 ( 25 - user pack license textbridge pro 11 is the simple and fast way to convert paper into edi ... <url>\n',
#  'cables to go 37211 lc / st duplex 62.5 / 125 multimode fiber patch cable ( 1 meter , green color-code with this 62.5 ... <url>\n',
#  '21x34 custom picture frame / poster frame 1.26 " wide complete medium brown frame ( 61999ca this frame is manufa ... <url>\n',
#  'i hate when i know im about to get in trouble when i did something bad and im trying to cover it #shameonme\n',
#  "my harry poster fell and i'm not tall enough to put it back up\n",
#  'horrible feeling when you try your best to make things work but the other person doesnt seem to care .\n',
#  '<user> can we work on my awkwardness ?\n',
#  '<user> wtf why not what am i gunna do without you ? !\n',
#  "silver springs mustard , beer ' n brat , 9.5- ounce squeeze bottles ( pack of 9 a four-time gold medal winner at th ... <url>\n",
#  'web design : the l line , the express line to learning ( wiley desktop editions ) ( paperback get on the fast track ... <url>\n',
# ...
#  "ok , even if you don't like sebastian you have to admit this is heartbreaking . <url> <url>\n",
#  "<user> nooo . hahaha , i feel like i'm gonna pass out i'm so tired . aaand i got a fucking cold sore today\n",
#  'trunk music ( harry bosch ) ( mass market paperback following on the heels of his extraordinary new york times be ... <url>\n',
#  "<user> to bad i can't go :/ i can't afford it\n",
#  "<user> i was wondering why you didn't answer me\n",
#  'swimming jellyfish aquarium ( toy this jellyfish aquarium is not your ordinary electric lamp . fill the glass co ... <url>\n',
#  'i want to dip dye someones hair\n',
#  "<user> alright alright . better try extra hard since you've ditched any other day we've tried to hangout\n",
#  '<user> both also have ah\n',
#  "idk why i'm still up , i guess i could use somebody to talk too\n",
#  'peerless pc930c - w adjustable tilt ceiling mount for 15 " to 24 " displays with 20 " to 34 " extension ( white item ... <url>\n',
#  '<user> why ? you going to #twtupipoh ke ? i miss you too bila nak hang out ?\n',
#  'hodgson mill 50/50 wheat flour , 5 - pounds ( pack of 6 <url>\n',
#  'just woke up shit ass mood\n',
#  '<user> yea i was asleep and was gonna ping ya but it says no reply till 5 or suin , u miss me ?\n',
#  'charlie rose ( november 4 , 2008 live coverage of the 2008 presidential election with doris kearns goodwin , mark ... <url>\n',
#  '<user> the advert one . going to saatchi on monday . i looked through the sem work ? why the workload so heavy ? are you interning ?\n',
#  "<user> so i take it you're staying in south carolina ... i'll miss you hereee but girl you're doin work triple majoring ! #smarty\n",
#  'awesome contributor for a long time mt <user> packers are releasing ot chad clifton today . failed a physical . had back surgery\n',
#  'graceland ( hardcover elvis presley purchased the graceland mansion in 1957and half a century later , it remain ... <url>\n',
#  'graceland ( hardcover elvis presley purchased the graceland mansion in 1957and half a century later , it remain ... <url>\n',
#  "there's this thing i use to be well acquainted with and lately there's distance between us oh right ... sleep\n",
#  '<user> , im bout to text you lovee !\n',
#  "<user> omfg , i'm craving them now\n",
#  '4d budget for mac 1.6 ( commercial 4d budget is equipped with probably the best and most universal importing to ... <url>\n',
#  "<user> can i get a rt for your irish fan ? guess wat ! your tickets were sold sooo fast i didn't get 1 booo x x\n",
#  'plato salmon strips 16oz ( pack of 3 ) ( misc . natural salmon strips with fresh pacific salmon , and other organic ... <url>\n',
#  'options for the beginner and beyond : unlock the opportunities and minimize the risks ( hardcover brief , careful ... <url>\n',
#  'options for the beginner and beyond : unlock the opportunities and minimize the risks ( hardcover brief , careful ... <url>\n',
#  '<user> amanda please can you tweet my mother <user> she is a massive fan and she is currently in bed ill xxx\n',
#  '<user> <user> ahhh then you cut my face\n',
#  'message stick ( paperback " one of the best novels in ten years of running this contest . " hackney literary awa ... <url>\n',
#  'beautiful stellenbosch photos from a travel feature in the new issue of <user> ( on newsstands now <url> #iwanttogothere\n',
#  'school is gonna be so boring tomorrow because judy & <user> will not be there .\n',
#  '<user> what ? why ? ... you are happy ? :/\n',
#  'an economic history of imperial madagascar , 1750-1895 : the rise and fall of an island empire . ( book review an a ... <url>\n',
#  'what is this ? ? rt <user> pls come and explode the brick wall in front of my heart with your big tanker ! lol !\n',
#  '<user> waaa , unfair that you got them ! #iwaaantthemmm #tantrum\n',
#  'the imitation of christ ( optimized for kindle <url>\n',
#  'the imitation of christ ( optimized for kindle <url>\n',
#  'pastato potato mac and yellow cheddar cheese ( panda ) , 6 - ounce ( pack of 6 <url>\n',
#  "ritz crackers ' n cheez , 0.95- ounce single serve packages ( pack of 60 <url>\n",
#  "<user> i'm so tired for singing honey i woke up at 5 am\n",
#  'the couple sitting next to me left , well fuck em too then , her hubby was awkward anyways >\n',
#  'i need someone to talk too ( ( (\n',
#  '<user> is asleep already bitch\n',
#  'skinit protective skin for ipod nano 4g ( skull pendant skins are a vinyl product that generally fits most devi ... <url>\n',
#  'loving more : the polyfidelity primer ( paperback <url>\n',
#  'carefree ultra protection regular pantiliners with wings-scented - 32 ct ( pack of 4 <url>\n',
#  'na lucky boy .. make our convoc sef class with my b\'day na " <user> hehehert <user> <user> wetin boys dey chop na ... induction\n',
#  '<user> i just wanted to see uncles dancing in the street while people blow shit up behind em\n',
#  'y has ma mood changed all of a sudden ? arghh . ma day hz bn fun , wish it ended the way it started . i tnk ma bible wil do nw .\n',
#  'planetary defense - a space viz production ( dvd synopsis - planetary defensewho will save earth ? scientists and ... <url>\n',
#  "ohh no ... i'm going to fall asleep in class . i can't even stay awake now and it doesn't start for another half hour . .\n",
#  'now i kno the meanin of " have you ever " by brandy ! ! ! omg\n',
#  '<user> i missed out too\n',
#  'my feet is the ugliest feet on earth ! ! #justsayin\n',
#  '" <user> wheress my plug ? ? ? <user>\n',
#  "<user> i'm not allowed either but once i'm 16 and have my own money my mam can just deal with it !\n",
#  'robert mugabe of zimbabwe ( in focus biographies recounts the story of the man who led the struggle for black p ... <url>\n',
#  'doc johnson rump shakers black medium vibrating butt plug ( health and beauty anal vibratrors are designed espe ... <url>\n',
#  'say my name ( drm-free with text-to-speech enabled , user-friendly mild-mannered newspaperman stanley t . branfor ... <url>\n',
#  "<user> ah i'm leaving after work this evening could have met up !\n",
#  "just saw video of the black lab that wouldn't leave his yellow lab buddy ( who had been hit & killed ) in middle of a busy road . #dogperson\n",
#  "<user> <user> i can't be pale any longer ! i've converted to the tanned side !\n",
#  "building stories ( pb there's a wonderful history and story to discover about every building in building storie ... <url>\n",
#  "building stories ( pb there's a wonderful history and story to discover about every building in building storie ... <url>\n",
#  "i still need to buy my <user> i am slackin '\n",
#  'i give up good night i have to go to bed now #estherr\n',
#  'disruptive technology and how to compete for the future - ( via brian solis <url>\n',
#  '13x22 custom picture frame / poster frame 2 " wide complete black satin mica smooth frame ( 74273 this frame is ... <url>\n',
#  '20x22 custom picture frame / poster frame 1.25 " wide complete copper river rock brown frame ( 26917 this frame ... <url>\n',
#  '20x22 custom picture frame / poster frame 1.25 " wide complete copper river rock brown frame ( 26917 this frame ... <url>\n',
#  'another major fucking l . major ...\n',
#  "rt <user> the killers ' saxophone player tommy marth reported dead from suicide <url>\n",
#  '2000-2001 honda cbr 929 : motorcycle hugger rear wheel fender ( silver motorcycle rear wheel hugger in black gla ... <url>\n',
#  "my phone is about to die and i'm in school ... i have to stay after for like 3 more hours\n",
#  '] midland gxt 1050vp4 36 - mile 50 - channel frs / gmrs two-way radio ( pair ) ( camo <url>\n',
#  '<user> sooo ! you aint usee too say that (\n',
#  '<user> down by home bargains ! fucking shit year this had turned out to be xx\n',
#  'video : ge brings manufacturing jobs back to u . s . ( cbs news share with friends : | | top news - business news , ... <url>\n',
#  "<user> ugghhh it was about the celtics i'm extremely angry\n",
#  "so i've been a little busy lately and totally abandoned the blog i'll be back soon hopefully xx\n",
#  '6 pack ( 3 photo black / 3 magenta ) remanufactured ink cartridge for hp 564xl ( cb322wn / cb324wn compatible wit ... <url>\n',
#  'puyol is acc a great player .. but why so ugly ?\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  '#pacerswinagain - for those counting at home , tonight is the pacers seventh consecutive victory ( 11-1 in april pacers 118 , <user> 109 .\n',
#  'rt <user> <user> rt <user> <user> colette < man what ? ! - - how u lose your virginity so fast ? < easy\n',
#  '<user> ohhh poop how have you been anyways ?\n',
#  'but let me stop complaining . there are kids in africa & ethiopia that are starving\n',
#  'but let me stop complaining . there are kids in africa & ethiopia that are starving\n',
#  'my braces keep catching my cheek today , really hurts\n',
#  '<user> you better not be lying to me soto but okay , deal !\n',
#  '<user> at 255 , cause i have no service in this room to text\n',
#  "#thethingis i've really been giving my all in this relationship & idont think he sees it\n",
#  'rt <user> ( ( ( this is y barca is losing ) ) ) ---> rt <user> i never knew ma followers hatred barca like this\n',
#  'my guy\'s balling on " hand-to-mouth " rt <user> is mode 9 making " lil change " ?\n',
#  "gawd i can't believe on saturday i'll be moving to ireland\n",
#  '<user> semo lazy . i am on my way to work leh . 9 hrs ! no need to die . can sleep in lecture right ?\n',
#  'when broken glass floats : growing up under the khmer rouge ( hardcover in a cambodian proverb , " when broken gla ... <url>\n',
#  'when broken glass floats : growing up under the khmer rouge ( hardcover in a cambodian proverb , " when broken gla ... <url>\n',
#  '<user> yeah , editing my menage now for may release , but then i have nothing due . trying to write , but i seem to have stalled keep ..\n',
#  '<user> awh boo ( well maybe we will get full soon !\n',
#  'ginger , crystallized slices ( 12/3 oz roland sliced crystallized ginger is coated with sugar and is packaged in ... <url>\n',
#  "yes , i got sad when i saw it and couldn't eat it lolrt <user> <user> but you know you would tear that cake d-izz-own\n",
#  'only 22 days\n',
#  '24x35 custom picture frame / poster frame 1.265 " wide complete green wood frame ( 440gr this frame is manufactu ... <url>\n',
#  'i know its long overdue ... but trying to follow all yall back ! i am such a procrastinator love ya\n',
#  '22x31 custom picture frame / poster frame 2 " wide complete black executive leather frame ( 74093 this frame is ... <url>\n',
#  "<user> yeah i'm going ! ! babe i didn't see you at all today\n",
#  'the old fortress of corfu ( greece a short travelogue though the fortifications and history of the old fortress ... <url>\n',
#  '<user> ur not thou\n',
#  '<user> and <user> evil people ! my lord will fight for me !\n',
#  '1998-2002 lincoln navigator 4dr chrome door handles / covers ( no keypad , with passenger keyhole 1998-2002 lincol ... <url>\n',
#  'mario badescu - buffering lotion - 1 oz ( health and beauty specifically designed to treat deep , cystic blemish ... <url>\n',
#  "a practitioner's guide to software test design ( hardcover a comprehensive , up-to-date and practical introducti ... <url>\n",
#  '11x36 custom picture frame / poster frame 2 " wide complete country oak brown frame (8 8063 this frame is manufa ... <url>\n',
#  'maxpedition 4.5- inch clip-on phone holster ( khaki great for small two-way radios , treo , iphone , palm , blackber ... <url>\n',
#  '<user> and i was right ... they let it slide\n',
#  'i just love how <user> never texts me back\n',
#  "can't find my one direction top so i can wear it for dance wahhh , got my old one , but its not as nice :/\n",
#  "<user> you're not coming to grand march ! ?\n",
#  "asics gel kinsei 3 t987n 0139 ( women's 7.5 , white capri blue lightning asics's premiere running shoe has under ... <url>\n",
#  '<user> i am though\n',
#  'garden of life - perfect food raw organic , 240 g powder ( health and beauty capture the raw power of the ... <url>\n',
#  'shine like it does - the anthology ( 1979-1997 ) ( audio cd shine like it does - the anthology ( 1979-1997 ) inxs o ... <url>\n',
#  'im wondering if <user> has left yet\n',
#  "<user> awesome can't believe that series is done\n",
#  "wooden mallet fold-away wall desk ( oak whether you've been searching for a convenient bill paying station , or ... <url>\n",
#  "wooden mallet fold-away wall desk ( oak whether you've been searching for a convenient bill paying station , or ... <url>\n",
#  'water and scratch resistant case for garmin tom tom magellan maestro 4.3 inch gps ( eva purple " this package in ... <url>\n',
#  "<user> its pouring down robyn ! so grim haha ! x i'm sitting in a sandwich bar killing time ! x\n",
#  '/ apple ipod touch 8 gb 4th generation ( white <url>\n',
#  '/ apple ipod touch 8 gb 4th generation ( white <url>\n',
#  '/ apple ipod touch 8 gb 4th generation ( white <url>\n',
#  '/ apple ipod touch 8 gb 4th generation ( white <url>\n',
#  '/ apple ipod touch 8 gb 4th generation ( white <url>\n',
#  '/ apple ipod touch 8 gb 4th generation ( white <url>\n',
#  '/ apple ipod touch 8 gb 4th generation ( white <url>\n',
#  '<user> niall , please , just one tweet for me ? just one retweet for me ? just , i love you my niallou and answer me ; thankyou (\n',
#  'happy birthday thornsten * husgss * i wishh you know thatt i miss you so muchh , the time we were together\n',
#  'its like antarctica in this bitch ... we need the heat fixed\n',
#  'stylecraft 30 " x 118 " spaced board and batten mahogany exterior shutters ( pair custom-made . southern styling . ... <url>\n',
#  "<user> please follow back , you follow my sister and i'm really jel\n",
#  "<user> tis not as bad as u people make it seem . don't let twitter get 2u . u beautiful inside k .\n",
#  '<user> said that she tries to respond to at least 10 barbz a day out of her 11 million ... can i be n that lucky 10 today plz\n',
#  "<user> shut up . i am not please don't eat me <3 cause if you eat me i'll be all gone and you'll be alone :/\n",
#  "i'm sorry i can't come ( rt <user> amazing show in jakarta ! the fans were crazy .. i will remember this one for a long time #indon\n",
#  '<user> nice ! ! congrats . ! ! ! :p today i failed a math test and a physic test . fuck\n',
#  ...]

# %%
# Transform array into Dataframe to use it easily
negative_DF = pd.DataFrame(data_neg)
positive_DF = pd.DataFrame(data_pos)
test_DF = pd.DataFrame(data_test)

# %%
negative_DF.head(10)
# Out:
#                                                    0
# 0  vinco tresorpack 6 ( difficulty 10 of 10 objec...
# 1  glad i dot have taks tomorrow ! ! #thankful #s...
# 2  1-3 vs celtics in the regular season = were fu...
# 3  <user> i could actually kill that girl i'm so ...
# 4  <user> <user> <user> i find that very hard to ...
# 5   wish i could be out all night tonight ! <user>\n
# 6                  <user> i got kicked out the wgm\n
# 7  rt <user> <user> <user> yes she is ! u tell it...
# 8                      why is she so perfect <url>\n
# 9  <user> hi harry ! did u havea good time in aus...

# %%
#Put everything to lowercase.
negative_DF[0] = negative_DF[0].astype(str).str.lower()
positive_DF[0] = positive_DF[0].astype(str).str.lower()
test_DF[0] = test_DF[0].astype(str).str.lower()

# %%
negative_DF.head(10)
# Out:
#                                                    0
# 0  vinco tresorpack 6 ( difficulty 10 of 10 objec...
# 1  glad i dot have taks tomorrow ! ! #thankful #s...
# 2  1-3 vs celtics in the regular season = were fu...
# 3  <user> i could actually kill that girl i'm so ...
# 4  <user> <user> <user> i find that very hard to ...
# 5   wish i could be out all night tonight ! <user>\n
# 6                  <user> i got kicked out the wgm\n
# 7  rt <user> <user> <user> yes she is ! u tell it...
# 8                      why is she so perfect <url>\n
# 9  <user> hi harry ! did u havea good time in aus...

# %%
# Take out user and url
negative_DF[0] = negative_DF[0].str.replace("<user>", '')
negative_DF[0] = negative_DF[0].str.replace("<url>", '')

positive_DF[0] = positive_DF[0].str.replace("<user>", '')
positive_DF[0] = positive_DF[0].str.replace("<url>", '')

test_DF[0] = test_DF[0].str.replace("<user>", '')
test_DF[0] = test_DF[0].str.replace("<url>", '')

# %%
negative_DF.head(10)
# Out:
#                                                    0
# 0  vinco tresorpack 6 ( difficulty 10 of 10 objec...
# 1  glad i dot have taks tomorrow ! ! #thankful #s...
# 2  1-3 vs celtics in the regular season = were fu...
# 3   i could actually kill that girl i'm so sorry ...
# 4       i find that very hard to believe im afraid\n
# 5         wish i could be out all night tonight ! \n
# 6                         i got kicked out the wgm\n
# 7  rt    yes she is ! u tell it ! my lips are clo...
# 8                           why is she so perfect \n
# 9   hi harry ! did u havea good time in aus ? i d...

# %%
#take out punctuation and non alphanumerical characters
negative_DF[0] = negative_DF[0].str.replace(r'[^\w\s]', '')
positive_DF[0] = positive_DF[0].str.replace(r'[^\w\s]', '')
test_DF[0] = test_DF[0].str.replace(r'[^\w\s]', '')

# %%
# take out numbers
negative_DF[0] = negative_DF[0].str.replace(r'[\d]', '')
positive_DF[0] = positive_DF[0].str.replace(r'[\d]', '')
test_DF[0] = test_DF[0].str.replace(r'[\d]', '')

# %%
negative_DF.head(10)
# Out:
#                                                    0
# 0  vinco tresorpack   difficulty  of  object  dis...
# 1  glad i dot have taks tomorrow   thankful start...
# 2   vs celtics in the regular season  were fucked...
# 3   i could actually kill that girl im so sorry   \n
# 4       i find that very hard to believe im afraid\n
# 5          wish i could be out all night tonight  \n
# 6                         i got kicked out the wgm\n
# 7  rt    yes she is  u tell it  my lips are close...
# 8                           why is she so perfect \n
# 9   hi harry  did u havea good time in aus  i did...

# %%
# tokenize each one.
negative_DF[0] = negative_DF[0].str.split()
positive_DF[0] = positive_DF[0].str.split()
test_DF[0] = test_DF[0].str.split()

# %%
negative_DF.head(10)
# Out:
#                                                    0
# 0  [vinco, tresorpack, difficulty, of, object, di...
# 1  [glad, i, dot, have, taks, tomorrow, thankful,...
# 2  [vs, celtics, in, the, regular, season, were, ...
# 3  [i, could, actually, kill, that, girl, im, so,...
# 4  [i, find, that, very, hard, to, believe, im, a...
# 5     [wish, i, could, be, out, all, night, tonight]
# 6                    [i, got, kicked, out, the, wgm]
# 7  [rt, yes, she, is, u, tell, it, my, lips, are,...
# 8                        [why, is, she, so, perfect]
# 9  [hi, harry, did, u, havea, good, time, in, aus...

# %%
# we remove the stop words
lang_set = nltk.corpus.stopwords.words('english')
negative_DF[0] = negative_DF[0].apply(lambda x: [word for word in x if word not in lang_set])
positive_DF[0] = positive_DF[0].apply(lambda x: [word for word in x if word not in lang_set])
test_DF[0] = test_DF[0].apply(lambda x: [word for word in x if word not in lang_set])

# %%
negative_DF.head(10)
# Out:
#                                                    0
# 0  [vinco, tresorpack, difficulty, object, disass...
# 1     [glad, dot, taks, tomorrow, thankful, startho]
# 2  [vs, celtics, regular, season, fucked, play, p...
# 3           [could, actually, kill, girl, im, sorry]
# 4                  [find, hard, believe, im, afraid]
# 5                      [wish, could, night, tonight]
# 6                                 [got, kicked, wgm]
# 7             [rt, yes, u, tell, lips, closed, okay]
# 8                                          [perfect]
# 9  [hi, harry, u, havea, good, time, aus, didnt, ...

# %%
#we remove the rt (retweets)
negative_DF[0] = negative_DF[0].apply(lambda x: [word for word in x if word not in ['rt']])
positive_DF[0] = positive_DF[0].apply(lambda x: [word for word in x if word not in ['rt']])
test_DF[0] = test_DF[0].apply(lambda x: [word for word in x if word not in ['rt']])

# %%
negative_DF.head(10)
# Out:
#                                                    0
# 0  [vinco, tresorpack, difficulty, object, disass...
# 1     [glad, dot, taks, tomorrow, thankful, startho]
# 2  [vs, celtics, regular, season, fucked, play, p...
# 3           [could, actually, kill, girl, im, sorry]
# 4                  [find, hard, believe, im, afraid]
# 5                      [wish, could, night, tonight]
# 6                                 [got, kicked, wgm]
# 7                 [yes, u, tell, lips, closed, okay]
# 8                                          [perfect]
# 9  [hi, harry, u, havea, good, time, aus, didnt, ...

# %% [markdown]
# J'ai remarké que stemmetize n'est pas toujours la meilleure chose à faire et tente du coup aussi de lemmetize. Ca nous rajoute de ce faite deux colonnes, pour qu'on puisse ensuite sélectionner la meilleure à utiliser.

# %%
# we stemmatize (get the root only) for each word
stemmer = nltk.stem.snowball.SnowballStemmer('english')    
negative_DF['stemmed'] = negative_DF[0].apply(lambda x: [stemmer.stem(word) for word in x])
positive_DF['stemmed'] = positive_DF[0].apply(lambda x: [stemmer.stem(word) for word in x])
test_DF['stemmed'] = test_DF[0].apply(lambda x: [stemmer.stem(word) for word in x])

# %%
negative_DF.head(10)

# %%
lemmatizer = nltk.stem.WordNetLemmatizer()
negative_DF['lemmed'] = negative_DF[0].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
positive_DF['lemmed'] = positive_DF[0].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
test_DF['lemmed'] = test_DF[0].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])

# %%
negative_DF.head(10)
# Out:
#                                                    0  \
# 0  [vinco, tresorpack, difficulty, object, disass...
# 1     [glad, dot, taks, tomorrow, thankful, startho]
# 2  [vs, celtics, regular, season, fucked, play, p...
# 3           [could, actually, kill, girl, im, sorry]
# 4                  [find, hard, believe, im, afraid]
# 5                      [wish, could, night, tonight]
# 6                                 [got, kicked, wgm]
# 7                 [yes, u, tell, lips, closed, okay]
# 8                                          [perfect]
# 9  [hi, harry, u, havea, good, time, aus, didnt, ...
#
#                                               lemmed
# 0  [vinco, tresorpack, difficulty, object, disass...
# 1     [glad, dot, taks, tomorrow, thankful, startho]
# 2  [v, celtic, regular, season, fucked, play, pla...
# 3           [could, actually, kill, girl, im, sorry]
# 4                  [find, hard, believe, im, afraid]
# 5                      [wish, could, night, tonight]
# 6                                 [got, kicked, wgm]
# 7                  [yes, u, tell, lip, closed, okay]
# 8                                          [perfect]
# 9  [hi, harry, u, havea, good, time, au, didnt, g...

# %% [markdown]
# Les lemmetizer ne semble pas amrcher à 100% donc essayons de faire les deux (donc utiliser le stem sur le lemmetizer)

# %%
lemmatizer = nltk.stem.WordNetLemmatizer()
stemmer = nltk.stem.snowball.SnowballStemmer('english')   
negative_DF['both'] = negative_DF['lemmed'].apply(lambda x: [stemmer.stem(word) for word in x])
positive_DF['both'] = positive_DF['lemmed'].apply(lambda x: [stemmer.stem(word) for word in x])
test_DF['both'] = test_DF['lemmed'].apply(lambda x: [stemmer.stem(word) for word in x])

# %%
positive_DF.head(10)
# Out:
#                                                    0  \
# 0  [dunno, justin, read, mention, justin, god, kn...
# 1  [logic, dumb, wont, even, crop, name, photo, tsk]
# 2     [put, casper, box, looved, battle, crakkbitch]
# 3  [thanks, sir, dont, trip, lil, mama, keep, doi...
# 4  [visiting, brother, tmr, bestest, birthday, gi...
# 5  [yay, lifecompleted, tweet, facebook, let, kno...
# 6  [dnextalbumtitle, feel, rollercoaster, life, s...
# 7  [workin, hard, hardly, workin, hardees, future...
# 8                          [saw, ill, replying, bit]
# 9                                           [belong]
#
#                                               lemmed  \
# 0  [dunno, justin, read, mention, justin, god, kn...
# 1  [logic, dumb, wont, even, crop, name, photo, tsk]
# 2     [put, casper, box, looved, battle, crakkbitch]
# 3  [thanks, sir, dont, trip, lil, mama, keep, doi...
# 4  [visiting, brother, tmr, bestest, birthday, gi...
# 5  [yay, lifecompleted, tweet, facebook, let, kno...
# 6  [dnextalbumtitle, feel, rollercoaster, life, s...
# 7  [workin, hard, hardly, workin, hardees, future...
# 8                          [saw, ill, replying, bit]
# 9                                           [belong]
#
#                                                 both  COLONNE
# 0  [dunno, justin, read, mention, justin, god, kn...      NaN
# 1  [logic, dumb, wont, even, crop, name, photo, tsk]      NaN
# 2        [put, casper, box, loov, battl, crakkbitch]      NaN
# 3  [thank, sir, dont, trip, lil, mama, keep, doin...      NaN
# 4  [visit, brother, tmr, bestest, birthday, gift,...      NaN
# 5  [yay, lifecomplet, tweet, facebook, let, know,...      NaN
# 6  [dnextalbumtitl, feel, rollercoast, life, song...      NaN
# 7  [workin, hard, hard, workin, harde, futur, cow...      NaN
# 8                             [saw, ill, repli, bit]      NaN
# 9                                           [belong]      NaN

# %% [markdown]
# Maintenant, il va falloir faire ce qui est proposé dans le pdf, donc par exemple, compter les mots qui apparaissent le plus dans negatif et positif, et pourquoi pas utiliser ça ensuite dans notre algorithme pour décider si c'est positif ou négatif dans le test. =)
#
# Quelques petites notes:
# - chaque tweet est un liste de mots
# - on a quatre colonnes: les mots de base du tweet, les mots mais stemmés (racine du mot), les mots mais lemmés (idem mais se veut plus précis) et un qui fait les deux (lem puis stem)
# - je pars du principe que tout est en anglais.

# %%
positive_DF['both'].to_csv(r'twitter-datasets/process_pos_full.txt', header=None, index=None, sep=' ', mode='a')

# %%
positive_DF['both'].as_matrix()
# Out:
#   File "<ipython-input-117-a99be03dca99>", line 1
#     positive_DF['both'].as_matrix(columns=(:))
#                                            ^
# SyntaxError: invalid syntax

# %%
with open('twitter-datasets/process_pos_full.txt', 'w', encoding='utf-8') as outfile:
         print(positive_DF['both'].as_matrix, file=outfile,)

# %%
# Out:
#   File "<ipython-input-60-07c16b485dd0>", line 1
#     scripts(/build_vocab.sh)
#             ^
# SyntaxError: invalid syntax
